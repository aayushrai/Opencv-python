# %%
import cv2
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread("rafale.jpeg")
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2 = cv2.imread("copy.jpeg")
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
img2.shape
# Out:
# (423, 450, 3)

# %%
img1.shape
# Out:
# (515, 915, 3)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1 = cv2.resize(img1,(400,400))
img2 = cv2.resize(img2,(400,400))

# %%
plt.imshow(img2)

# %%
plt.imshow(img1)

# %%
blend = cv2.addWeighted(src1=img1,alpha=0.8,src2=img2,beta=0.2,gamma=0)

# %%
plt.imshow(blend)
