# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("brick.jpeg").astype(np.float32)/255
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(im)

# %%
gamma = 1/4  #increase or decrease brightness
result = np.power(img,gamma)
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(result)

# %%
gamma = 2  #increase or decrease brightness
result = np.power(img,gamma)
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(result)

# %%
kernel = np.ones(shape=(5,5),dtype=np.float32)/25

# %%
dst = cv2.filter2D(img,-1,kernel)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(dst)

# %%
blur = cv2.blur(img,ksize=(10,10))

# %%
plt.imshow(blur)

# %%
gussian = cv2.GaussianBlur(img,(5,5),10)

# %%
plt.imshow(gussian)

# %%
m = cv2.medianBlur(img,5)
plt.imshow(m)
