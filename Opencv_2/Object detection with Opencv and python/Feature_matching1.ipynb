# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
vlc = cv2.imread("vlc.jpg",0)
plt.imshow(img,cmap='gray')

# %%
cap = cv2.imread("capture.png",0)
plt.imshow(cap,cmap='gray')

# %%
orb = cv2.ORB_create()

# %%
kp1,des1 = orb.detectAndCompute(vlc,None)
kp2,des2 = orb.detectAndCompute(cap,None)

# %%
bf = cv2.BFMatcher(cv2.NORM_HAMMING,crossCheck = True)

# %%
matches = bf.match(des1,des2)

# %%
matches = sorted(matches,key=lambda x:x.distance) #just sorting according to distance

# %%
vlc_matches = cv2.drawMatches(vlc,kp1,cap,kp2,matches[:25],None,flags=2)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(vlc_matches,cmap="gray")
